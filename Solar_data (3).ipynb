# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sample_Solar_Production_Data_.csv')

# %%
df.head()
# Out:
#   Site_ID        Date  Solar_Irradiance_kWh/m2  Energy_Generated_kWh  \
# 0  SITE_1  01/05/2025                     5.31                 47.40
# 1  SITE_1  02/05/2025                     4.20                 36.96
# 2  SITE_1  03/05/2025                     6.91                 54.03
# 3  SITE_1  04/05/2025                     5.51                 43.73
# 4  SITE_1  05/05/2025                     5.60                 48.60
#
#    Battery_SOC_%  Load_Consumed_kWh  Generator_Run_Hours  \
# 0           83.9              91.91                 0.31
# 1           76.1              99.57                 0.04
# 2           50.9              62.84                 0.61
# 3           76.7              59.76                 0.58
# 4           52.0              86.00                 1.18
#
#    Ambient_Temperature_C
# 0                   27.3
# 1                   39.5
# 2                   32.9
# 3                   30.5
# 4                   25.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site_ID                  90 non-null     object
#  1   Date                     90 non-null     object
#  2   Solar_Irradiance_kWh/m2  90 non-null     float64
#  3   Energy_Generated_kWh     90 non-null     float64
#  4   Battery_SOC_%            90 non-null     float64
#  5   Load_Consumed_kWh        90 non-null     float64
#  6   Generator_Run_Hours      90 non-null     float64
#  7   Ambient_Temperature_C    90 non-null     float64
# dtypes: float64(6), object(2)
# memory usage: 5.8+ KB

# %%
df.describe().T
# Out:
#                          count       mean        std    min      25%     50%  \
# Solar_Irradiance_kWh/m2   90.0   5.777000   1.046013   4.02   5.0000   5.840
# Energy_Generated_kWh      90.0  48.239556   9.319288  32.95  39.9000  47.500
# Battery_SOC_%             90.0  70.303333  19.019195  40.40  52.5750  72.700
# Load_Consumed_kWh         90.0  85.860444  20.509982  51.16  67.1375  87.860
# Generator_Run_Hours       90.0   0.969000   0.613606   0.01   0.5300   0.905
# Ambient_Temperature_C     90.0  31.985556   4.326027  25.20  28.3250  32.400
#
#                               75%     max
# Solar_Irradiance_kWh/m2    6.7850    7.47
# Energy_Generated_kWh      55.9400   66.54
# Battery_SOC_%             87.3250   99.20
# Load_Consumed_kWh        102.3125  119.98
# Generator_Run_Hours        1.4500    1.99
# Ambient_Temperature_C     35.4750   39.60

# %%
df.select_dtypes(include='number').hist(figsize=(12, 8), bins=20)
# Out:
# array([[<Axes: title={'center': 'Solar_Irradiance_kWh/m2'}>,
#         <Axes: title={'center': 'Energy_Generated_kWh'}>],
#        [<Axes: title={'center': 'Battery_SOC_%'}>,
#         <Axes: title={'center': 'Load_Consumed_kWh'}>],
#        [<Axes: title={'center': 'Generator_Run_Hours'}>,
#         <Axes: title={'center': 'Ambient_Temperature_C'}>]], dtype=object)

# %%
for col in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col], color='skyblue')
    plt.title(f"Boxplot of {col}")
    plt.tight_layout()
    plt.show()

# %%
df.head()
# Out:
#   Site_ID        Date  Solar_Irradiance_kWh/m2  Energy_Generated_kWh  \
# 0  SITE_1  01/05/2025                     5.31                 47.40
# 1  SITE_1  02/05/2025                     4.20                 36.96
# 2  SITE_1  03/05/2025                     6.91                 54.03
# 3  SITE_1  04/05/2025                     5.51                 43.73
# 4  SITE_1  05/05/2025                     5.60                 48.60
#
#    Battery_SOC_%  Load_Consumed_kWh  Generator_Run_Hours  \
# 0           83.9              91.91                 0.31
# 1           76.1              99.57                 0.04
# 2           50.9              62.84                 0.61
# 3           76.7              59.76                 0.58
# 4           52.0              86.00                 1.18
#
#    Ambient_Temperature_C
# 0                   27.3
# 1                   39.5
# 2                   32.9
# 3                   30.5
# 4                   25.7

# %%
for col in df.select_dtypes(include='object').columns:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, data=df, palette='Set2')
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Taofeeq\AppData\Local\Temp\ipykernel_15844\2201025554.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2')
# C:\Users\Taofeeq\AppData\Local\Temp\ipykernel_15844\2201025554.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2')

# %%
numerical_vars = df.select_dtypes(include='number')
correlation_matrix = numerical_vars.corr()
print(correlation_matrix)
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Numerical Variables")
plt.tight_layout()
plt.show()
# Out:
#                          Solar_Irradiance_kWh/m2  Energy_Generated_kWh  \
# Solar_Irradiance_kWh/m2                 1.000000              0.960106
# Energy_Generated_kWh                    0.960106              1.000000
# Battery_SOC_%                          -0.040350             -0.017992
# Load_Consumed_kWh                       0.012738             -0.031629
# Generator_Run_Hours                    -0.167685             -0.193671
# Ambient_Temperature_C                   0.174824              0.133726
#
#                          Battery_SOC_%  Load_Consumed_kWh  \
# Solar_Irradiance_kWh/m2      -0.040350           0.012738
# Energy_Generated_kWh         -0.017992          -0.031629
# Battery_SOC_%                 1.000000           0.086935
# Load_Consumed_kWh             0.086935           1.000000
# Generator_Run_Hours          -0.007949           0.077571
# Ambient_Temperature_C         0.002590           0.057350
#
# ...

# %%
x = df['Solar_Irradiance_kWh/m2']
y = df['Energy_Generated_kWh']
plt.scatter(x,y)
plt.title("Solar_Irradiance_kWh/m2 vs Energy_Generated_kWh")
plt.xlabel("Solar_Irradiance_kWh/m2")
plt.ylabel("Energy_Generated_kWh")
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   Site_ID        Date  Solar_Irradiance_kWh/m2  Energy_Generated_kWh  \
# 0  SITE_1  01/05/2025                     5.31                 47.40
# 1  SITE_1  02/05/2025                     4.20                 36.96
# 2  SITE_1  03/05/2025                     6.91                 54.03
# 3  SITE_1  04/05/2025                     5.51                 43.73
# 4  SITE_1  05/05/2025                     5.60                 48.60
#
#    Battery_SOC_%  Load_Consumed_kWh  Generator_Run_Hours  \
# 0           83.9              91.91                 0.31
# 1           76.1              99.57                 0.04
# 2           50.9              62.84                 0.61
# 3           76.7              59.76                 0.58
# 4           52.0              86.00                 1.18
#
#    Ambient_Temperature_C
# 0                   27.3
# 1                   39.5
# 2                   32.9
# 3                   30.5
# 4                   25.7

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
#df['Year'] = df['Date'].dt.month
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['Day'] = df['Date'].dt.day

# %%
df.head()
# Out:
#   Site_ID       Date  Solar_Irradiance_kWh/m2  Energy_Generated_kWh  \
# 0  SITE_1 2025-05-01                     5.31                 47.40
# 1  SITE_1 2025-05-02                     4.20                 36.96
# 2  SITE_1 2025-05-03                     6.91                 54.03
# 3  SITE_1 2025-05-04                     5.51                 43.73
# 4  SITE_1 2025-05-05                     5.60                 48.60
#
#    Battery_SOC_%  Load_Consumed_kWh  Generator_Run_Hours  \
# 0           83.9              91.91                 0.31
# 1           76.1              99.57                 0.04
# 2           50.9              62.84                 0.61
# 3           76.7              59.76                 0.58
# 4           52.0              86.00                 1.18
#
#    Ambient_Temperature_C  Month  Year  Day
# 0                   27.3      5  2025    1
# 1                   39.5      5  2025    2
# 2                   32.9      5  2025    3
# ...

# %%
group_day = df.groupby('Day')[['Solar_Irradiance_kWh/m2','Energy_Generated_kWh']].sum().reset_index()
print(group_day)
# Out:
#     Day  Solar_Irradiance_kWh/m2  Energy_Generated_kWh
# 0     1                    15.86                132.58
# 1     2                    18.42                159.32
# 2     3                    18.39                151.36
# 3     4                    19.46                159.56
# 4     5                    18.29                151.77
# 5     6                    19.52                158.73
# 6     7                    17.21                140.08
# 7     8                    14.22                121.81
# 8     9                    20.20                160.86
# 9    10                    16.98                145.02
# 10   11                    19.42                166.28
# 11   12                    15.54                137.32
# 12   13                    17.16                137.87
# 13   14                    17.72                135.47
# 14   15                    19.00                162.56
# 15   16                    17.97                153.43
# ...

# %%
fig, ax1 = plt.subplots(figsize = (18,8))
ax1.plot(group_day['Day'], group_day['Solar_Irradiance_kWh/m2'], color = 'blue', label = 'Solar_Irradiance_kWh/m2')
ax1.set_ylabel('Solar_Irradiance_kWh/m2', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_xticks(range(len(group_day['Day'])))
ax1.set_xticklabels(group_day['Day'], rotation=0) 
#plotting the line plots
ax2 = ax1.twinx()
ax2.plot(group_day['Day'], group_day['Energy_Generated_kWh'], color='green', marker='o', label='Energy_Generated_kWh')
ax2.set_ylabel('Energy_Generated_kWh')
fig.suptitle('\nDay-wise Composite Chart: Day, Energy_Generated_kWh, Solar_Irradiance_kWh/m2', fontsize=14)
fig.tight_layout()
fig.subplots_adjust(top=0.92)
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)

plt.show()

# %%
#Linear_Regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df.head()
# Out:
#   Site_ID       Date  Solar_Irradiance_kWh/m2  Energy_Generated_kWh  \
# 0  SITE_1 2025-05-01                     5.31                 47.40
# 1  SITE_1 2025-05-02                     4.20                 36.96
# 2  SITE_1 2025-05-03                     6.91                 54.03
# 3  SITE_1 2025-05-04                     5.51                 43.73
# 4  SITE_1 2025-05-05                     5.60                 48.60
#
#    Battery_SOC_%  Load_Consumed_kWh  Generator_Run_Hours  \
# 0           83.9              91.91                 0.31
# 1           76.1              99.57                 0.04
# 2           50.9              62.84                 0.61
# 3           76.7              59.76                 0.58
# 4           52.0              86.00                 1.18
#
#    Ambient_Temperature_C  Month  Year  Day
# 0                   27.3      5  2025    1
# 1                   39.5      5  2025    2
# 2                   32.9      5  2025    3
# ...

# %%
features = ['Site_ID','Solar_Irradiance_kWh/m2', 'Battery_SOC_%',	'Load_Consumed_kWh',	'Generator_Run_Hours',	'Ambient_Temperature_C',	'Year',	'Month',	'Day']
x = pd.get_dummies(df[features], drop_first = True)
y = df['Energy_Generated_kWh']

# %%
#xtrain_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
#model training
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#predict and evaluate
y_pred = model.predict(x_test)
print("mean squared error:", mean_squared_error(y_test, y_pred))
print("R2 score:", r2_score(y_test, y_pred))
# Out:
# mean squared error: 5.1811098867508445
# R2 score: 0.9505958693122267

# %%
plt.scatter(y_test, y_pred, alpha=0.5, color = 'red')
plt.xlabel('Energy_Generated_kWh')
plt.ylabel('PEnergy_Generated_kWh')
plt.title('Actual vs Predicted Energy_Generated_kWh')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', s=60)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # reference line
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted Energy Generation")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Create and display a table of actual vs predicted values
results_df = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})
print("Actual vs Predicted Values")
results_df.head(20)
# Out:
# Actual vs Predicted Values
#     Actual  Predicted
# 0    65.11  61.095043
# 1    35.39  37.218427
# 2    45.34  44.614082
# 3    58.79  56.806568
# 4    47.40  43.410199
# 5    54.88  52.275621
# 6    40.17  39.242689
# 7    60.65  61.913746
# 8    42.38  44.591864
# 9    60.88  58.576682
# 10   32.95  35.199452
# 11   50.54  49.289790
# 12   59.80  59.205602
# 13   46.37  46.401672
# 14   35.07  32.552070
# 15   48.60  45.507607
# 16   36.55  39.770869
# 17   34.72  35.571985

# %%
residuals = y_test - y_pred

plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, bins=30, color="purple")
plt.title("Distribution of Residuals")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
importance = pd.Series(model.coef_, index=x_train.columns)

# Sort by absolute importance
importance = importance.reindex(importance.abs().sort_values(ascending=False).index)

# Plot
plt.figure(figsize=(10, 6))
importance.plot(kind='barh', color='teal')
plt.title('Feature Importance (Linear Regression Coefficients)')
plt.xlabel('Coefficient Value')
plt.gca().invert_yaxis()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import streamlit as st
